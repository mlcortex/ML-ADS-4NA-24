# %%
import pandas as pd
import matplotlib.pyplot as plt



# URL do dataset Wine
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# Nome das colunas
column_names_pt_br = [
    'classe',
    'alcool',
    'acido_malico',
    'cinzas',
    'alcalinidade_de_cinzas',
    'magnesio',
    'fenois_totais',
    'flavanoides',
    'fenois_nao_flavanoides',
    'proantocianinas',
    'intensidade_de_cor',
    'matiz',
    'od280_od315_de_vinhos_diluidos',
    'prolina'
]

# Ler o arquivo CSV com as colunas especificadas, definindo a coluna 'classe' como object
vinhos = pd.read_csv(url, names=column_names_pt_br, dtype={'classe': object})

# %% [markdown]
# 1. Análise Exploratória de Variáveis

# %%
# Contagem de classes
print(vinhos['classe'].value_counts())
# Out:
# classe
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %% [markdown]
# 1.1 Alcool

# %%
# Alcool
print(vinhos['alcool'].describe())
print("============================================")
print(vinhos['alcool'].value_counts())
print(vinhos['alcool'])
# Out:
# count    178.000000
# mean      13.000618
# std        0.811827
# min       11.030000
# 25%       12.362500
# 50%       13.050000
# 75%       13.677500
# max       14.830000
# Name: alcool, dtype: float64
# ...
# alcool
# 13.05    6
# 12.37    6
# 12.08    5
# 12.29    4
# 12.42    3
#         ..
# 13.72    1
# 13.29    1
# 13.74    1
# 13.77    1
# 14.13    1
# Name: count, Length: 126, dtype: int64
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcool, Length: 178, dtype: float64

# %% [markdown]
# acido_malico

# %%
#acido_malico
print(vinhos['acido_malico'].describe())
print("============================================")
print(vinhos['acido_malico'].value_counts())
print("============================================")
print(vinhos['acido_malico'])

# %% [markdown]
# cinzas

# %%
#cinzas
print(vinhos['cinzas'].describe())
print("============================================")
print(vinhos['cinzas'].value_counts())
print("============================================")
print(vinhos['cinzas'])

# %% [markdown]
# alcalinidade_de_cinzas

# %%
#alcalinidade_de_cinzas
print(vinhos['alcalinidade_de_cinzas'].describe())
print("============================================")
print(vinhos['alcalinidade_de_cinzas'].value_counts())
print("============================================")
print(vinhos['alcalinidade_de_cinzas'])

# %% [markdown]
# magnesio

# %%
#magnesio
print(vinhos['magnesio'].describe())
print("============================================")
print(vinhos['magnesio'].value_counts())
print("============================================")
print(vinhos['magnesio'])

# %% [markdown]
# fenois_totais

# %%
#fenois_totais
print(vinhos['fenois_totais'].describe())
print("============================================")
print(vinhos['fenois_totais'].value_counts())
print("============================================")
print(vinhos['fenois_totais'])

# %% [markdown]
# flavanoides

# %%
#flavanoides
print(vinhos['flavanoides'].describe())
print("============================================")
print(vinhos['flavanoides'].value_counts())
print("============================================")
print(vinhos['flavanoides'])

# %% [markdown]
# fenois_nao_flavanoides

# %%
#fenois_nao_flavanoides
print(vinhos['fenois_nao_flavanoides'].describe())
print("============================================")
print(vinhos['fenois_nao_flavanoides'].value_counts())
print("============================================")
print(vinhos['fenois_nao_flavanoides'])

# %% [markdown]
# proantocianinas

# %%
#proantocianinas
print(vinhos['proantocianinas'].describe())
print("============================================")
print(vinhos['proantocianinas'].value_counts())
print("============================================")
print(vinhos['proantocianinas'])

# %% [markdown]
# intensidade de cor

# %%
#intensidade_de_cor
print(vinhos['intensidade_de_cor'].describe())
print("============================================")
print(vinhos['intensidade_de_cor'].value_counts())
print("============================================")
print(vinhos['intensidade_de_cor'])

# %% [markdown]
# matiz

# %%
#matiz
print(vinhos['matiz'].describe())
print("============================================")
print(vinhos['matiz'].value_counts())
print("============================================")
print(vinhos['matiz'])

# %% [markdown]
# od280 od315 de vinhos diluidos

# %%
#od280_od315_de_vinhos_diluidos
print(vinhos['od280_od315_de_vinhos_diluidos'].describe())
print("============================================")
print(vinhos['od280_od315_de_vinhos_diluidos'].value_counts())
print("============================================")
print(vinhos['od280_od315_de_vinhos_diluidos'])

# %% [markdown]
# prolina

# %%
#prolina
print(vinhos['prolina'].describe())
print("============================================")
print(vinhos['prolina'].value_counts())
print("============================================")
print(vinhos['prolina'])

# %% [markdown]
# 2. Criação de Boxplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#Magnesio
sns.boxplot(data=vinhos[['magnesio',]])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# prolina

# %%
sns.boxplot(data=vinhos[['prolina',]])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# cinzas

# %%
sns.boxplot(data=vinhos[['cinzas',]])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# alcool

# %%
sns.boxplot(data=vinhos[['alcool',]])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
import pandas as pd



colunas = ['magnesio', 'fenois_totais', 'acido_malico', 'alcool']

for col in colunas:
    vinhos.boxplot(column=col, by='classe')
    plt.title(f'Boxplot de {col} segregado por classe')
    plt.suptitle('=======================================================')
    plt.xlabel('Classe')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# 4. Criação de Histograma
# Crie um histograma para visualizar a distribuição dos dados na coluna:

# %%
import matplotlib.pyplot as plt


plt.hist(vinhos['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma de Fenois Totais')
plt.show()

# %% [markdown]
# Crie um histograma da coluna fenois_totais, filtrando apenas a classe 3, utilizando 10 bins.

# %%
plt.hist(vinhos[vinhos['classe'] == 3]['fenois_totais'], bins=10)
plt.xlabel('Fenois Totais')
plt.ylabel('Frequência')
plt.title('Histograma de Fenois Totais')
plt.show()
